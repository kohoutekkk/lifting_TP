# %%
import pandas as pd

# %%
squat_snatch_max = 73
power_snatch_max = 65
snatch_deadlift_max = 90

clean_and_jerk_max = 93
squat_clean_max = 93
power_clean_max = 80
clean_deadlift_max = 110

split_jerk_max = 93
power_jerk_max = 0
push_jerk_max = 74

back_squat_max = 120 
front_sqat_max = 105
overhed_squat_max = 60

snatch_weakness = "stabilita vzpažení"
clean_weakness = "nedokončený výtah"
jerk_weakness = "výpich není kolmo"

cycle_length = 6

# %%
# Out:
# 1

# %%
cycle_and_blocks = {
    6:(
        ('volume', ('normal', 'normal')),
        ('strength',('heavy', 'normal')),
        ('competiton', ('heavy', 'light')),
    ),
    8:(
        ('volume', ('normal','heavy', 'light')),
        ('strength',('heavy', 'normal', 'normal')),
        ('competiton', ('heavy', 'light')),
    ),
    10:(
        ('volume', ('normal', 'heavy', 'light')),
        ('strength',('heavy', 'normal', 'heavy', 'light')),
        ('competiton', ('heavy','heavy', 'light')),
    ),
    12:(
        ('volume', ('normal','normal', 'heavy', 'light')),
        ('strength',('normal','normal', 'heavy', 'light')),
        ('competiton', ('normal','normal', 'heavy', 'light')),
    )
    }

# %%
# ratios
snatch_to_caj = squat_snatch_max/squat_clean_max
caj_to_bs = clean_and_jerk_max/back_squat_max
fs_to_bs = front_sqat_max/back_squat_max
jerk_to_clean = split_jerk_max/squat_clean_max

# %%
basic_excercises = {2:{
    'volume':{
        'day_1':(
            'skoky/plyo',
            'trh do polo + tech. od st.',
            'pozved trhový',
            'dřep zadní',
            'výr. tlak',
        ),
        'day_2':(
            'skoky/plyo',
            'technika/polo',
            'výtah/pozved',
            'dřep',
            'vzpažení',
        )
        },
    'strength':{
        'day_1':(
            'skoky/plyo',
            'primer',
            'technika/polo',
            'výtah/pozved',
            'dřep',
            'vzpažení',
        ),
        'day_2':(
            'skoky/plyo',
            'primer',
            'technika/polo',
            'výtah/pozved',
            'dřep',
            'vzpažení',
        )
        },
    'competition':{
        'day_1':(
            'primer',
            'technika/polo',
            'technika/polo',
            'výtah/pozved',
            'dřep',
        ),
        'day_2':(
            'primer',
            'technika/polo',
            'technika/polo',
            'dřep',
            'vzpažení',
        )
    }
    }
}

# %%
{'primer': ,'tech_variation':}

# %%
weakness_fixes = {
    'snatch':{

    },
    'clean':{

    },
    'jerk':{

    },
}

# %%
basic_excercises[2]['competition']['day_2']
# Out:
# ('primer', 'technika/polo', 'technika/polo', 'dřep', 'vzpažení')
